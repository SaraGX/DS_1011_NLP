# %%
import pickle as pkl
import re
import random
import os
import numpy as np
from collections import Counter
from sklearn.feature_extraction import stop_words
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from collections import Counter

max_vocab_size = 10000
# save index 0 for unk and 1 for pad
PAD_IDX = 0
UNK_IDX = 1

def build_vocab(all_tokens,max_vocab_size = 10000 ):
    # Returns:
    # id2token: list of tokens, where id2token[i] returns token that corresponds to token i
    # token2id: dictionary where keys represent tokens and corresponding values represent indices
    token_counter = Counter(all_tokens)
    vocab, count = zip(*token_counter.most_common(max_vocab_size))
    id2token = list(vocab)
    token2id = dict(zip(vocab, range(2,2+len(vocab)))) 
    id2token = ['<pad>', '<unk>'] + id2token
    token2id['<pad>'] = PAD_IDX 
    token2id['<unk>'] = UNK_IDX
    return token2id, id2token


def token2index_dataset(tokens_data, token2id):
    indices_data = []
    for tokens in tokens_data:
        index_list = [token2id[token] if token in token2id else UNK_IDX for token in tokens]
        indices_data.append(index_list)
    return indices_data

# %%
MAX_SENTENCE_LENGTH = 200

import numpy as np
import torch
from torch.utils.data import Dataset

class NewsGroupDataset(Dataset):
    """
    Class that represents a train/validation/test dataset that's readable for PyTorch
    Note that this class inherits torch.utils.data.Dataset
    """
    
    def __init__(self, data_list, target_list):
        """
        @param data_list: list of newsgroup tokens 
        @param target_list: list of newsgroup targets 

        """
        self.data_list = data_list
        self.target_list = target_list
        assert (len(self.data_list) == len(self.target_list))

    def __len__(self):
        return len(self.data_list)
        
    def __getitem__(self, key):
        """
        Triggered when you call dataset[i]
        """
        
        token_idx = self.data_list[key][:MAX_SENTENCE_LENGTH]
        label = self.target_list[key]
        return [token_idx, len(token_idx), label]

def newsgroup_collate_func(batch):
    """
    Customized function for DataLoader that dynamically pads the batch so that all 
    data have the same length
    """
    data_list = []
    label_list = []
    length_list = []
    #print("collate batch: ", batch[0][0])
    #batch[0][0] = batch[0][0][:MAX_SENTENCE_LENGTH]
    for datum in batch:
        label_list.append(datum[2])
        length_list.append(datum[1])
    # padding
    for datum in batch:
        padded_vec = np.pad(np.array(datum[0]), 
                                pad_width=((0,MAX_SENTENCE_LENGTH-datum[1])), 
                                mode="constant", constant_values=0)
        data_list.append(padded_vec)
    return [torch.from_numpy(np.array(data_list)), torch.LongTensor(length_list), torch.LongTensor(label_list)]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class BagOfWords(nn.Module):
    """
    BagOfWords classification model
    """
    def __init__(self, vocab_size, emb_dim):
        """
        @param vocab_size: size of the vocabulary. 
        @param emb_dim: size of the word embedding
        """
        super(BagOfWords, self).__init__()
        # pay attention to padding_idx 
        self.embed = nn.Embedding(vocab_size, emb_dim, padding_idx=0) #stores embeddings of a fixed dictionary and size
        self.linear = nn.Linear(emb_dim,20)
    
    def forward(self, data, length):
        """
        
        @param data: matrix of size (batch_size, max_sentence_length). Each row in data represents a 
            review that is represented using n-gram index. Note that they are padded to have same length.
        @param length: an int tensor of size (batch_size), which represents the non-trivial (excludes padding)
            length of each sentences in the data.
        """
        out = self.embed(data)
        out = torch.sum(out, dim=1)
        out /= length.view(length.size()[0],1).expand_as(out).float()
     
        # return logits
        out = self.linear(out.float())
        return out

# %%
def test_model(loader, model):
    """
    Help function that tests the model's performance on a dataset
    @param: loader - data loader for the dataset to test against
    """
    correct = 0
    total = 0
    model.eval()
    for data, lengths, labels in loader:
        data_batch, length_batch, label_batch = data, lengths, labels
        outputs = F.softmax(model(data_batch, length_batch), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]
        
        total += labels.size(0)
        correct += predicted.eq(labels.view_as(predicted)).sum().item()
    return (100 * correct / total)

# %%
def data_loader(n_gram, max_vocab_size = 10000):
    train_data_tokens = pkl.load(open('tokens/train_set_tokens_%s_gram.p' % n_gram, "rb"))
    all_train_tokens = pkl.load(open('tokens/all_train_tokens_%s_gram.p' % n_gram, "rb"))
    val_data_tokens = pkl.load(open('tokens/val_set_tokens_%s_gram.p' % n_gram, "rb"))
    test_data_tokens = pkl.load(open('tokens/test_set_tokens_%s_gram.p' % n_gram, "rb"))

    train_label = pkl.load(open('tokens/train_labels.p', "rb"))
    val_label = pkl.load(open('tokens/val_labels.p' , "rb"))
    test_label = pkl.load(open('tokens/test_labels.p' , "rb"))

    token2id, id2token = build_vocab(all_train_tokens, max_vocab_size)
    train_data_indices = token2index_dataset(train_data_tokens, token2id)
    val_data_indices = token2index_dataset(val_data_tokens, token2id)
    test_data_indices = token2index_dataset(test_data_tokens, token2id)
    BATCH_SIZE = 32
    train_dataset = NewsGroupDataset(train_data_indices, train_label)
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                               batch_size=BATCH_SIZE,
                                               collate_fn=newsgroup_collate_func,
                                               shuffle=True)

    val_dataset = NewsGroupDataset(val_data_indices, val_label)
    val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                               batch_size=BATCH_SIZE,
                                               collate_fn=newsgroup_collate_func,
                                               shuffle=True)

    test_dataset = NewsGroupDataset(test_data_indices, test_label)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                               batch_size=BATCH_SIZE,
                                               collate_fn=newsgroup_collate_func,
                                               shuffle=False)
    return train_loader, val_loader, test_loader

# %%
def compare_model(train_loader, val_loader, test_loader,
                  num_epochs = 5, emb_dim = 500, vocab_size = 10002, learning_rate = 0.001, 
                  optimizer_name = 'Adam', momentum = 0.9, annealing_learing = False, 
                  print_ = True, model_del = True ):

    model = BagOfWords(vocab_size, emb_dim)

    # Criterion and Optimizer
    criterion = torch.nn.CrossEntropyLoss()  
    if optimizer_name == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
            
    elif optimizer_name == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum = momentum)
    else: 
        return('Wrong Optimizer')
    
    if annealing_learing:
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
    val_history = []  
    train_history = []
    for epoch in range(num_epochs):
        if annealing_learing:
            scheduler.step()
            
        for i, (data, lengths, labels) in enumerate(train_loader):
            model.train()
            data_batch, length_batch, label_batch = data, lengths, labels
            optimizer.zero_grad()
            outputs = model(data_batch, length_batch)
            loss = criterion(outputs, label_batch)
            loss.backward()
            optimizer.step()
            # validate every 100 iterations
            if i > 0 and i % 100 == 0:
                # validate
                train_acc = test_model(train_loader, model)
                val_acc = test_model(val_loader, model)
                val_history.append(val_acc)
                train_history.append(train_acc)
                
                if print_:
                    print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format( 
                           epoch+1, num_epochs, i+1, len(train_loader), val_acc))
            
                
    test_acc = test_model(test_loader, model)
    if model_del:
        del(model)
    return train_history, val_history, test_acc

# %%
n_grams = [1, 2, 3, 4]
vocab_sizes = [10002, 50000, 100000]
embed_dims = [100, 200, 500 ]
learning_rates = [0.01, 0.05, 0.001, 0.0001]
optimizers = ['Adam', 'SGD']
momentums = [0.1, 0.5, 0.9]

# %% [markdown]
# ### plot the history of train acc and val acc

# %%
import pickle as pkl
table= {}
train_loader, val_loader, test_loader = data_loader(1)
train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader )
table['val_history'] = val_history
table['train_history'] = train_history
pkl.dump(table, open('accuracy/n_gram_acc_history.p', 'wb'))
# Out:
# Epoch: [1/5], Step: [101/625], Validation Acc: 64.06
# Epoch: [1/5], Step: [201/625], Validation Acc: 71.64
# Epoch: [1/5], Step: [301/625], Validation Acc: 74.9
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.74
# Epoch: [1/5], Step: [501/625], Validation Acc: 80.92
# Epoch: [1/5], Step: [601/625], Validation Acc: 82.04
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.26
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.92
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.4
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.38
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.18
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.36
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.9
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.02
# Epoch: [3/5], Step: [301/625], Validation Acc: 86.28
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.46
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.76
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.86
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.6
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.92
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.84
# Epoch: [4/5], Step: [401/625], Validation Acc: 87.06
# Epoch: [4/5], Step: [501/625], Validation Acc: 87.1
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.16
# Epoch: [5/5], Step: [101/625], Validation Acc: 87.38
# Epoch: [5/5], Step: [201/625], Validation Acc: 87.12
# Epoch: [5/5], Step: [301/625], Validation Acc: 87.28
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.18
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.2
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.02

# %%
print(pd.DataFrame(table))
# Out:
#     train_history  val_history
# 0          63.835        64.06
# 1          72.265        71.64
# 2          76.005        74.90
# 3          80.400        78.74
# 4          82.640        80.92
# 5          84.310        82.04
# 6          85.750        83.26
# 7          86.850        83.92
# 8          87.695        84.40
# 9          87.375        84.38
# 10         89.015        85.18
# 11         89.440        85.36
# 12         90.135        85.90
# 13         90.410        86.02
# 14         90.565        86.28
# 15         91.145        86.46
# 16         91.495        86.76
# 17         91.850        86.86
# 18         92.010        86.60
# 19         92.320        86.92
# 20         92.575        86.84
# 21         92.880        87.06
# 22         93.260        87.10
# 23         93.325        87.16
# 24         93.680        87.38
# 25         93.445        87.12
# 26         93.745        87.28
# 27         94.185        87.18
# 28         94.370        87.20
# 29         94.335        87.02

# %%
sns.set()
fig,ax=plt.subplots(figsize=(15,10))
l=locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)
for i in table.keys():
    l[i],=ax.plot(x, table[i], label=i)

ax.legend(loc = 'best')
plt.title('train acc and val acc')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)
plt.savefig('figure/n_gram_acc_history.jpg')
plt.show()

# %% [markdown]
# ### Compare Epochs

# %%
epochs = [5, 10, 15, 20]
table= {}
train_loader, val_loader, test_loader = data_loader(1)
for i in epochs:
    print('epochs:', i)
    train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, num_epochs = i )
    table[i] = val_history
# Out:
# epochs: 5
# Epoch: [1/5], Step: [101/625], Validation Acc: 62.04
# Epoch: [1/5], Step: [201/625], Validation Acc: 71.3
# Epoch: [1/5], Step: [301/625], Validation Acc: 74.68
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.06
# Epoch: [1/5], Step: [501/625], Validation Acc: 79.3
# Epoch: [1/5], Step: [601/625], Validation Acc: 80.28
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.02
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.74
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.42
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.94
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.62
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.6
# Epoch: [3/5], Step: [101/625], Validation Acc: 86.38
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.5
# Epoch: [3/5], Step: [301/625], Validation Acc: 86.62
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.76
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.48
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.7
# Epoch: [4/5], Step: [101/625], Validation Acc: 87.12
# Epoch: [4/5], Step: [201/625], Validation Acc: 87.18
# Epoch: [4/5], Step: [301/625], Validation Acc: 87.02
# Epoch: [4/5], Step: [401/625], Validation Acc: 87.04
# Epoch: [4/5], Step: [501/625], Validation Acc: 87.22
# Epoch: [4/5], Step: [601/625], Validation Acc: 86.96
# Epoch: [5/5], Step: [101/625], Validation Acc: 87.3
# Epoch: [5/5], Step: [201/625], Validation Acc: 87.12
# Epoch: [5/5], Step: [301/625], Validation Acc: 87.24
# Epoch: [5/5], Step: [401/625], Validation Acc: 86.96
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.44
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.08
# epochs: 10
# Epoch: [1/10], Step: [101/625], Validation Acc: 67.9
# Epoch: [1/10], Step: [201/625], Validation Acc: 72.12
# Epoch: [1/10], Step: [301/625], Validation Acc: 75.48
# Epoch: [1/10], Step: [401/625], Validation Acc: 78.74
# Epoch: [1/10], Step: [501/625], Validation Acc: 80.24
# Epoch: [1/10], Step: [601/625], Validation Acc: 81.2
# Epoch: [2/10], Step: [101/625], Validation Acc: 82.9
# Epoch: [2/10], Step: [201/625], Validation Acc: 83.42
# Epoch: [2/10], Step: [301/625], Validation Acc: 84.46
# Epoch: [2/10], Step: [401/625], Validation Acc: 84.68
# Epoch: [2/10], Step: [501/625], Validation Acc: 85.34
# Epoch: [2/10], Step: [601/625], Validation Acc: 85.8
# Epoch: [3/10], Step: [101/625], Validation Acc: 85.88
# Epoch: [3/10], Step: [201/625], Validation Acc: 86.36
# Epoch: [3/10], Step: [301/625], Validation Acc: 86.34
# Epoch: [3/10], Step: [401/625], Validation Acc: 86.38
# Epoch: [3/10], Step: [501/625], Validation Acc: 86.04
# Epoch: [3/10], Step: [601/625], Validation Acc: 86.14
# Epoch: [4/10], Step: [101/625], Validation Acc: 86.72
# Epoch: [4/10], Step: [201/625], Validation Acc: 87.04
# Epoch: [4/10], Step: [301/625], Validation Acc: 87.1
# Epoch: [4/10], Step: [401/625], Validation Acc: 86.76
# Epoch: [4/10], Step: [501/625], Validation Acc: 86.78
# Epoch: [4/10], Step: [601/625], Validation Acc: 87.16
# Epoch: [5/10], Step: [101/625], Validation Acc: 86.56
# Epoch: [5/10], Step: [201/625], Validation Acc: 86.66
# Epoch: [5/10], Step: [301/625], Validation Acc: 87.18
# Epoch: [5/10], Step: [401/625], Validation Acc: 87.3
# Epoch: [5/10], Step: [501/625], Validation Acc: 86.72
# Epoch: [5/10], Step: [601/625], Validation Acc: 86.82
# Epoch: [6/10], Step: [101/625], Validation Acc: 87.28
# Epoch: [6/10], Step: [201/625], Validation Acc: 87.0
# Epoch: [6/10], Step: [301/625], Validation Acc: 86.98
# Epoch: [6/10], Step: [401/625], Validation Acc: 87.32
# Epoch: [6/10], Step: [501/625], Validation Acc: 87.36
# Epoch: [6/10], Step: [601/625], Validation Acc: 87.42
# Epoch: [7/10], Step: [101/625], Validation Acc: 87.7
# Epoch: [7/10], Step: [201/625], Validation Acc: 87.4
# Epoch: [7/10], Step: [301/625], Validation Acc: 87.2
# Epoch: [7/10], Step: [401/625], Validation Acc: 87.08
# Epoch: [7/10], Step: [501/625], Validation Acc: 87.14
# Epoch: [7/10], Step: [601/625], Validation Acc: 87.06
# Epoch: [8/10], Step: [101/625], Validation Acc: 86.54
# Epoch: [8/10], Step: [201/625], Validation Acc: 86.94
# Epoch: [8/10], Step: [301/625], Validation Acc: 86.02
# Epoch: [8/10], Step: [401/625], Validation Acc: 86.8
# Epoch: [8/10], Step: [501/625], Validation Acc: 86.68
# Epoch: [8/10], Step: [601/625], Validation Acc: 86.62
# Epoch: [9/10], Step: [101/625], Validation Acc: 86.92
# Epoch: [9/10], Step: [201/625], Validation Acc: 86.34
# Epoch: [9/10], Step: [301/625], Validation Acc: 86.52
# Epoch: [9/10], Step: [401/625], Validation Acc: 86.3
# Epoch: [9/10], Step: [501/625], Validation Acc: 86.62
# Epoch: [9/10], Step: [601/625], Validation Acc: 86.8
# Epoch: [10/10], Step: [101/625], Validation Acc: 86.7
# Epoch: [10/10], Step: [201/625], Validation Acc: 86.7
# Epoch: [10/10], Step: [301/625], Validation Acc: 86.5
# Epoch: [10/10], Step: [401/625], Validation Acc: 86.06
# Epoch: [10/10], Step: [501/625], Validation Acc: 86.24
# Epoch: [10/10], Step: [601/625], Validation Acc: 86.28
# epochs: 15
# Epoch: [1/15], Step: [101/625], Validation Acc: 59.28
# Epoch: [1/15], Step: [201/625], Validation Acc: 70.42
# Epoch: [1/15], Step: [301/625], Validation Acc: 75.76
# Epoch: [1/15], Step: [401/625], Validation Acc: 78.54
# Epoch: [1/15], Step: [501/625], Validation Acc: 79.4
# Epoch: [1/15], Step: [601/625], Validation Acc: 82.24
# Epoch: [2/15], Step: [101/625], Validation Acc: 82.88
# Epoch: [2/15], Step: [201/625], Validation Acc: 84.24
# Epoch: [2/15], Step: [301/625], Validation Acc: 84.04
# Epoch: [2/15], Step: [401/625], Validation Acc: 85.04
# Epoch: [2/15], Step: [501/625], Validation Acc: 85.4
# Epoch: [2/15], Step: [601/625], Validation Acc: 85.72
# Epoch: [3/15], Step: [101/625], Validation Acc: 86.14
# Epoch: [3/15], Step: [201/625], Validation Acc: 85.92
# Epoch: [3/15], Step: [301/625], Validation Acc: 86.2
# Epoch: [3/15], Step: [401/625], Validation Acc: 86.56
# Epoch: [3/15], Step: [501/625], Validation Acc: 86.4
# Epoch: [3/15], Step: [601/625], Validation Acc: 86.48
# Epoch: [4/15], Step: [101/625], Validation Acc: 86.92
# Epoch: [4/15], Step: [201/625], Validation Acc: 86.74
# Epoch: [4/15], Step: [301/625], Validation Acc: 86.66
# Epoch: [4/15], Step: [401/625], Validation Acc: 86.78
# Epoch: [4/15], Step: [501/625], Validation Acc: 87.08
# Epoch: [4/15], Step: [601/625], Validation Acc: 86.76
# Epoch: [5/15], Step: [101/625], Validation Acc: 87.08
# Epoch: [5/15], Step: [201/625], Validation Acc: 87.2
# Epoch: [5/15], Step: [301/625], Validation Acc: 87.2
# Epoch: [5/15], Step: [401/625], Validation Acc: 87.06
# Epoch: [5/15], Step: [501/625], Validation Acc: 87.02
# Epoch: [5/15], Step: [601/625], Validation Acc: 87.02
# Epoch: [6/15], Step: [101/625], Validation Acc: 87.1
# Epoch: [6/15], Step: [201/625], Validation Acc: 86.92
# Epoch: [6/15], Step: [301/625], Validation Acc: 87.04
# Epoch: [6/15], Step: [401/625], Validation Acc: 87.16
# Epoch: [6/15], Step: [501/625], Validation Acc: 87.1
# Epoch: [6/15], Step: [601/625], Validation Acc: 87.32
# Epoch: [7/15], Step: [101/625], Validation Acc: 87.0
# Epoch: [7/15], Step: [201/625], Validation Acc: 87.1
# Epoch: [7/15], Step: [301/625], Validation Acc: 86.92
# Epoch: [7/15], Step: [401/625], Validation Acc: 87.02
# Epoch: [7/15], Step: [501/625], Validation Acc: 87.02
# Epoch: [7/15], Step: [601/625], Validation Acc: 87.0
# Epoch: [8/15], Step: [101/625], Validation Acc: 87.06
# Epoch: [8/15], Step: [201/625], Validation Acc: 87.04
# Epoch: [8/15], Step: [301/625], Validation Acc: 86.7
# Epoch: [8/15], Step: [401/625], Validation Acc: 86.48
# Epoch: [8/15], Step: [501/625], Validation Acc: 86.92
# Epoch: [8/15], Step: [601/625], Validation Acc: 87.12
# Epoch: [9/15], Step: [101/625], Validation Acc: 86.76
# Epoch: [9/15], Step: [201/625], Validation Acc: 86.3
# Epoch: [9/15], Step: [301/625], Validation Acc: 86.4
# Epoch: [9/15], Step: [401/625], Validation Acc: 86.72
# Epoch: [9/15], Step: [501/625], Validation Acc: 86.5
# Epoch: [9/15], Step: [601/625], Validation Acc: 86.34
# Epoch: [10/15], Step: [101/625], Validation Acc: 86.44
# Epoch: [10/15], Step: [201/625], Validation Acc: 85.98
# Epoch: [10/15], Step: [301/625], Validation Acc: 86.02
# Epoch: [10/15], Step: [401/625], Validation Acc: 86.18
# Epoch: [10/15], Step: [501/625], Validation Acc: 86.2
# Epoch: [10/15], Step: [601/625], Validation Acc: 86.24
# Epoch: [11/15], Step: [101/625], Validation Acc: 86.5
# Epoch: [11/15], Step: [201/625], Validation Acc: 86.46
# Epoch: [11/15], Step: [301/625], Validation Acc: 86.1
# Epoch: [11/15], Step: [401/625], Validation Acc: 86.06
# Epoch: [11/15], Step: [501/625], Validation Acc: 85.84
# Epoch: [11/15], Step: [601/625], Validation Acc: 86.02
# Epoch: [12/15], Step: [101/625], Validation Acc: 85.8
# Epoch: [12/15], Step: [201/625], Validation Acc: 86.02
# Epoch: [12/15], Step: [301/625], Validation Acc: 85.76
# Epoch: [12/15], Step: [401/625], Validation Acc: 85.86
# Epoch: [12/15], Step: [501/625], Validation Acc: 85.74
# Epoch: [12/15], Step: [601/625], Validation Acc: 85.68
# Epoch: [13/15], Step: [101/625], Validation Acc: 85.76
# Epoch: [13/15], Step: [201/625], Validation Acc: 85.68
# Epoch: [13/15], Step: [301/625], Validation Acc: 85.62
# Epoch: [13/15], Step: [401/625], Validation Acc: 85.48
# Epoch: [13/15], Step: [501/625], Validation Acc: 85.52
# Epoch: [13/15], Step: [601/625], Validation Acc: 85.56
# Epoch: [14/15], Step: [101/625], Validation Acc: 85.48
# Epoch: [14/15], Step: [201/625], Validation Acc: 85.38
# Epoch: [14/15], Step: [301/625], Validation Acc: 85.44
# Epoch: [14/15], Step: [401/625], Validation Acc: 85.3
# Epoch: [14/15], Step: [501/625], Validation Acc: 85.12
# Epoch: [14/15], Step: [601/625], Validation Acc: 84.98
# Epoch: [15/15], Step: [101/625], Validation Acc: 85.1
# Epoch: [15/15], Step: [201/625], Validation Acc: 85.0
# Epoch: [15/15], Step: [301/625], Validation Acc: 84.82
# Epoch: [15/15], Step: [401/625], Validation Acc: 85.08
# Epoch: [15/15], Step: [501/625], Validation Acc: 85.02
# Epoch: [15/15], Step: [601/625], Validation Acc: 84.78
# epochs: 20
# Epoch: [1/20], Step: [101/625], Validation Acc: 64.92
# Epoch: [1/20], Step: [201/625], Validation Acc: 70.54
# Epoch: [1/20], Step: [301/625], Validation Acc: 75.2
# Epoch: [1/20], Step: [401/625], Validation Acc: 78.54
# Epoch: [1/20], Step: [501/625], Validation Acc: 79.38
# Epoch: [1/20], Step: [601/625], Validation Acc: 82.3
# Epoch: [2/20], Step: [101/625], Validation Acc: 82.78
# Epoch: [2/20], Step: [201/625], Validation Acc: 83.74
# Epoch: [2/20], Step: [301/625], Validation Acc: 84.48
# Epoch: [2/20], Step: [401/625], Validation Acc: 85.02
# Epoch: [2/20], Step: [501/625], Validation Acc: 84.4
# Epoch: [2/20], Step: [601/625], Validation Acc: 84.96
# Epoch: [3/20], Step: [101/625], Validation Acc: 85.72
# Epoch: [3/20], Step: [201/625], Validation Acc: 85.82
# Epoch: [3/20], Step: [301/625], Validation Acc: 85.96
# Epoch: [3/20], Step: [401/625], Validation Acc: 86.42
# Epoch: [3/20], Step: [501/625], Validation Acc: 86.64
# Epoch: [3/20], Step: [601/625], Validation Acc: 86.5
# Epoch: [4/20], Step: [101/625], Validation Acc: 86.98
# Epoch: [4/20], Step: [201/625], Validation Acc: 86.58
# Epoch: [4/20], Step: [301/625], Validation Acc: 87.04
# Epoch: [4/20], Step: [401/625], Validation Acc: 87.06
# Epoch: [4/20], Step: [501/625], Validation Acc: 86.96
# Epoch: [4/20], Step: [601/625], Validation Acc: 87.18
# Epoch: [5/20], Step: [101/625], Validation Acc: 87.04
# Epoch: [5/20], Step: [201/625], Validation Acc: 87.48
# Epoch: [5/20], Step: [301/625], Validation Acc: 87.14
# Epoch: [5/20], Step: [401/625], Validation Acc: 87.08
# Epoch: [5/20], Step: [501/625], Validation Acc: 86.84
# Epoch: [5/20], Step: [601/625], Validation Acc: 87.16
# Epoch: [6/20], Step: [101/625], Validation Acc: 87.04
# Epoch: [6/20], Step: [201/625], Validation Acc: 86.78
# Epoch: [6/20], Step: [301/625], Validation Acc: 86.88
# Epoch: [6/20], Step: [401/625], Validation Acc: 86.96
# Epoch: [6/20], Step: [501/625], Validation Acc: 87.02
# Epoch: [6/20], Step: [601/625], Validation Acc: 87.0
# Epoch: [7/20], Step: [101/625], Validation Acc: 87.08
# Epoch: [7/20], Step: [201/625], Validation Acc: 87.06
# Epoch: [7/20], Step: [301/625], Validation Acc: 87.02
# Epoch: [7/20], Step: [401/625], Validation Acc: 86.94
# Epoch: [7/20], Step: [501/625], Validation Acc: 86.94
# Epoch: [7/20], Step: [601/625], Validation Acc: 86.62
# Epoch: [8/20], Step: [101/625], Validation Acc: 86.84
# Epoch: [8/20], Step: [201/625], Validation Acc: 86.5
# Epoch: [8/20], Step: [301/625], Validation Acc: 86.86
# Epoch: [8/20], Step: [401/625], Validation Acc: 86.6
# Epoch: [8/20], Step: [501/625], Validation Acc: 86.58
# Epoch: [8/20], Step: [601/625], Validation Acc: 86.68
# Epoch: [9/20], Step: [101/625], Validation Acc: 86.64
# Epoch: [9/20], Step: [201/625], Validation Acc: 86.56
# Epoch: [9/20], Step: [301/625], Validation Acc: 86.48
# Epoch: [9/20], Step: [401/625], Validation Acc: 86.3
# Epoch: [9/20], Step: [501/625], Validation Acc: 85.94
# Epoch: [9/20], Step: [601/625], Validation Acc: 86.62
# Epoch: [10/20], Step: [101/625], Validation Acc: 85.9
# Epoch: [10/20], Step: [201/625], Validation Acc: 86.16
# Epoch: [10/20], Step: [301/625], Validation Acc: 86.12
# Epoch: [10/20], Step: [401/625], Validation Acc: 86.36
# Epoch: [10/20], Step: [501/625], Validation Acc: 86.22
# Epoch: [10/20], Step: [601/625], Validation Acc: 86.28
# Epoch: [11/20], Step: [101/625], Validation Acc: 86.2
# Epoch: [11/20], Step: [201/625], Validation Acc: 86.06
# Epoch: [11/20], Step: [301/625], Validation Acc: 86.2
# Epoch: [11/20], Step: [401/625], Validation Acc: 85.94
# Epoch: [11/20], Step: [501/625], Validation Acc: 86.0
# Epoch: [11/20], Step: [601/625], Validation Acc: 85.76
# Epoch: [12/20], Step: [101/625], Validation Acc: 85.88
# Epoch: [12/20], Step: [201/625], Validation Acc: 85.92
# Epoch: [12/20], Step: [301/625], Validation Acc: 85.86
# Epoch: [12/20], Step: [401/625], Validation Acc: 85.86
# Epoch: [12/20], Step: [501/625], Validation Acc: 85.26
# Epoch: [12/20], Step: [601/625], Validation Acc: 85.82
# Epoch: [13/20], Step: [101/625], Validation Acc: 85.4
# Epoch: [13/20], Step: [201/625], Validation Acc: 85.58
# Epoch: [13/20], Step: [301/625], Validation Acc: 85.5
# Epoch: [13/20], Step: [401/625], Validation Acc: 85.5
# Epoch: [13/20], Step: [501/625], Validation Acc: 85.5
# Epoch: [13/20], Step: [601/625], Validation Acc: 85.24
# Epoch: [14/20], Step: [101/625], Validation Acc: 85.6
# Epoch: [14/20], Step: [201/625], Validation Acc: 85.54
# Epoch: [14/20], Step: [301/625], Validation Acc: 85.48
# Epoch: [14/20], Step: [401/625], Validation Acc: 85.22
# Epoch: [14/20], Step: [501/625], Validation Acc: 85.02
# Epoch: [14/20], Step: [601/625], Validation Acc: 85.12
# Epoch: [15/20], Step: [101/625], Validation Acc: 85.14
# Epoch: [15/20], Step: [201/625], Validation Acc: 85.3
# Epoch: [15/20], Step: [301/625], Validation Acc: 85.24
# Epoch: [15/20], Step: [401/625], Validation Acc: 85.02
# Epoch: [15/20], Step: [501/625], Validation Acc: 85.22
# Epoch: [15/20], Step: [601/625], Validation Acc: 85.0
# Epoch: [16/20], Step: [101/625], Validation Acc: 84.96
# Epoch: [16/20], Step: [201/625], Validation Acc: 84.96
# Epoch: [16/20], Step: [301/625], Validation Acc: 84.62
# Epoch: [16/20], Step: [401/625], Validation Acc: 84.78
# Epoch: [16/20], Step: [501/625], Validation Acc: 84.82
# Epoch: [16/20], Step: [601/625], Validation Acc: 84.2
# Epoch: [17/20], Step: [101/625], Validation Acc: 84.58
# Epoch: [17/20], Step: [201/625], Validation Acc: 84.82
# Epoch: [17/20], Step: [301/625], Validation Acc: 84.64
# Epoch: [17/20], Step: [401/625], Validation Acc: 84.56
# Epoch: [17/20], Step: [501/625], Validation Acc: 84.66
# Epoch: [17/20], Step: [601/625], Validation Acc: 84.54
# Epoch: [18/20], Step: [101/625], Validation Acc: 84.38
# Epoch: [18/20], Step: [201/625], Validation Acc: 84.28
# Epoch: [18/20], Step: [301/625], Validation Acc: 84.36
# Epoch: [18/20], Step: [401/625], Validation Acc: 84.22
# Epoch: [18/20], Step: [501/625], Validation Acc: 84.2
# Epoch: [18/20], Step: [601/625], Validation Acc: 84.12
# Epoch: [19/20], Step: [101/625], Validation Acc: 84.24
# Epoch: [19/20], Step: [201/625], Validation Acc: 84.2
# Epoch: [19/20], Step: [301/625], Validation Acc: 84.0
# Epoch: [19/20], Step: [401/625], Validation Acc: 84.28
# Epoch: [19/20], Step: [501/625], Validation Acc: 84.16
# Epoch: [19/20], Step: [601/625], Validation Acc: 84.24
# Epoch: [20/20], Step: [101/625], Validation Acc: 84.28
# Epoch: [20/20], Step: [201/625], Validation Acc: 84.22
# Epoch: [20/20], Step: [301/625], Validation Acc: 84.1
# Epoch: [20/20], Step: [401/625], Validation Acc: 84.2
# Epoch: [20/20], Step: [501/625], Validation Acc: 84.22
# Epoch: [20/20], Step: [601/625], Validation Acc: 84.12

# %%
pkl.dump(table, open('accuracy/compare_epochs.p', "wb"))

# %%
sns.set()
fig,ax=plt.subplots(figsize=(15,10))
l=locals()

x = np.arange(0 , 20, 1/6).reshape(-1,1)

for n in epochs:
    y = table[n]
    label = "epochs: "+str(n)
    l[label],=ax.plot(x[:len(y)], y, label=label)
ax.legend(loc = 'best')
plt.title('Model hyperparameters: epochs')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)
plt.savefig('figure/epochs_acc.jpg')

plt.show()

# %% [markdown]
# ### Compare n-gram

# %%
table= {}

for i in n_grams:
    print('n_gram:%s'%i)
    train_loader, val_loader, test_loader = data_loader(i)
    train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader )
    table[i] = val_history
# Out:
# n_gram:1
# Epoch: [1/5], Step: [101/625], Validation Acc: 65.94
# Epoch: [1/5], Step: [201/625], Validation Acc: 71.64
# Epoch: [1/5], Step: [301/625], Validation Acc: 75.2
# Epoch: [1/5], Step: [401/625], Validation Acc: 77.7
# Epoch: [1/5], Step: [501/625], Validation Acc: 80.5
# Epoch: [1/5], Step: [601/625], Validation Acc: 82.46
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.3
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.62
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.68
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.7
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.48
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.56
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.8
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.14
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.96
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.34
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.62
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.72
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.94
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.96
# Epoch: [4/5], Step: [301/625], Validation Acc: 87.0
# Epoch: [4/5], Step: [401/625], Validation Acc: 87.12
# Epoch: [4/5], Step: [501/625], Validation Acc: 87.26
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.2
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.78
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.94
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.4
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.18
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.22
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.2
# n_gram:2
# Epoch: [1/5], Step: [101/625], Validation Acc: 64.58
# Epoch: [1/5], Step: [201/625], Validation Acc: 68.34
# Epoch: [1/5], Step: [301/625], Validation Acc: 73.26
# Epoch: [1/5], Step: [401/625], Validation Acc: 76.38
# Epoch: [1/5], Step: [501/625], Validation Acc: 78.32
# Epoch: [1/5], Step: [601/625], Validation Acc: 80.48
# Epoch: [2/5], Step: [101/625], Validation Acc: 81.18
# Epoch: [2/5], Step: [201/625], Validation Acc: 81.98
# Epoch: [2/5], Step: [301/625], Validation Acc: 82.46
# Epoch: [2/5], Step: [401/625], Validation Acc: 83.3
# Epoch: [2/5], Step: [501/625], Validation Acc: 84.0
# Epoch: [2/5], Step: [601/625], Validation Acc: 84.08
# Epoch: [3/5], Step: [101/625], Validation Acc: 84.76
# Epoch: [3/5], Step: [201/625], Validation Acc: 84.82
# Epoch: [3/5], Step: [301/625], Validation Acc: 84.58
# Epoch: [3/5], Step: [401/625], Validation Acc: 85.46
# Epoch: [3/5], Step: [501/625], Validation Acc: 85.34
# Epoch: [3/5], Step: [601/625], Validation Acc: 85.74
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.02
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.86
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.06
# Epoch: [4/5], Step: [401/625], Validation Acc: 85.6
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.48
# Epoch: [4/5], Step: [601/625], Validation Acc: 86.24
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.24
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.36
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.28
# Epoch: [5/5], Step: [401/625], Validation Acc: 85.78
# Epoch: [5/5], Step: [501/625], Validation Acc: 86.28
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.2
# n_gram:3
# Epoch: [1/5], Step: [101/625], Validation Acc: 61.76
# Epoch: [1/5], Step: [201/625], Validation Acc: 64.06
# Epoch: [1/5], Step: [301/625], Validation Acc: 71.64
# Epoch: [1/5], Step: [401/625], Validation Acc: 76.4
# Epoch: [1/5], Step: [501/625], Validation Acc: 78.62
# Epoch: [1/5], Step: [601/625], Validation Acc: 80.46
# Epoch: [2/5], Step: [101/625], Validation Acc: 82.32
# Epoch: [2/5], Step: [201/625], Validation Acc: 80.6
# Epoch: [2/5], Step: [301/625], Validation Acc: 83.12
# Epoch: [2/5], Step: [401/625], Validation Acc: 83.54
# Epoch: [2/5], Step: [501/625], Validation Acc: 83.64
# Epoch: [2/5], Step: [601/625], Validation Acc: 84.26
# Epoch: [3/5], Step: [101/625], Validation Acc: 84.42
# Epoch: [3/5], Step: [201/625], Validation Acc: 84.74
# Epoch: [3/5], Step: [301/625], Validation Acc: 84.98
# Epoch: [3/5], Step: [401/625], Validation Acc: 84.88
# Epoch: [3/5], Step: [501/625], Validation Acc: 84.92
# Epoch: [3/5], Step: [601/625], Validation Acc: 85.74
# Epoch: [4/5], Step: [101/625], Validation Acc: 85.36
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.3
# Epoch: [4/5], Step: [301/625], Validation Acc: 85.24
# Epoch: [4/5], Step: [401/625], Validation Acc: 85.64
# Epoch: [4/5], Step: [501/625], Validation Acc: 85.64
# Epoch: [4/5], Step: [601/625], Validation Acc: 86.04
# Epoch: [5/5], Step: [101/625], Validation Acc: 85.88
# Epoch: [5/5], Step: [201/625], Validation Acc: 85.94
# Epoch: [5/5], Step: [301/625], Validation Acc: 85.84
# Epoch: [5/5], Step: [401/625], Validation Acc: 85.86
# Epoch: [5/5], Step: [501/625], Validation Acc: 85.84
# Epoch: [5/5], Step: [601/625], Validation Acc: 85.82
# n_gram:4
# Epoch: [1/5], Step: [101/625], Validation Acc: 50.32
# Epoch: [1/5], Step: [201/625], Validation Acc: 66.32
# Epoch: [1/5], Step: [301/625], Validation Acc: 73.66
# Epoch: [1/5], Step: [401/625], Validation Acc: 73.78
# Epoch: [1/5], Step: [501/625], Validation Acc: 77.44
# Epoch: [1/5], Step: [601/625], Validation Acc: 76.42
# Epoch: [2/5], Step: [101/625], Validation Acc: 81.96
# Epoch: [2/5], Step: [201/625], Validation Acc: 81.72
# Epoch: [2/5], Step: [301/625], Validation Acc: 83.26
# Epoch: [2/5], Step: [401/625], Validation Acc: 83.88
# Epoch: [2/5], Step: [501/625], Validation Acc: 83.78
# Epoch: [2/5], Step: [601/625], Validation Acc: 84.26
# Epoch: [3/5], Step: [101/625], Validation Acc: 84.56
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.08
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.28
# Epoch: [3/5], Step: [401/625], Validation Acc: 84.54
# Epoch: [3/5], Step: [501/625], Validation Acc: 85.26
# Epoch: [3/5], Step: [601/625], Validation Acc: 85.3
# Epoch: [4/5], Step: [101/625], Validation Acc: 85.58
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.48
# Epoch: [4/5], Step: [301/625], Validation Acc: 85.68
# Epoch: [4/5], Step: [401/625], Validation Acc: 85.36
# Epoch: [4/5], Step: [501/625], Validation Acc: 85.64
# Epoch: [4/5], Step: [601/625], Validation Acc: 86.12
# Epoch: [5/5], Step: [101/625], Validation Acc: 85.58
# Epoch: [5/5], Step: [201/625], Validation Acc: 85.92
# Epoch: [5/5], Step: [301/625], Validation Acc: 85.78
# Epoch: [5/5], Step: [401/625], Validation Acc: 85.68
# Epoch: [5/5], Step: [501/625], Validation Acc: 85.92
# Epoch: [5/5], Step: [601/625], Validation Acc: 85.96

# %%
pkl.dump(table, open('accuracy/compare_n_gram.p', "wb"))

# %%
print(pd.DataFrame(table))
# Out:
#         1      2      3      4
# 0   65.94  64.58  61.76  50.32
# 1   71.64  68.34  64.06  66.32
# 2   75.20  73.26  71.64  73.66
# 3   77.70  76.38  76.40  73.78
# 4   80.50  78.32  78.62  77.44
# 5   82.46  80.48  80.46  76.42
# 6   83.30  81.18  82.32  81.96
# 7   83.62  81.98  80.60  81.72
# 8   84.68  82.46  83.12  83.26
# 9   84.70  83.30  83.54  83.88
# 10  85.48  84.00  83.64  83.78
# 11  85.56  84.08  84.26  84.26
# 12  85.80  84.76  84.42  84.56
# 13  86.14  84.82  84.74  85.08
# 14  85.96  84.58  84.98  85.28
# 15  86.34  85.46  84.88  84.54
# 16  86.62  85.34  84.92  85.26
# 17  86.72  85.74  85.74  85.30
# 18  86.94  86.02  85.36  85.58
# 19  86.96  85.86  85.30  85.48
# 20  87.00  86.06  85.24  85.68
# 21  87.12  85.60  85.64  85.36
# 22  87.26  86.48  85.64  85.64
# 23  87.20  86.24  86.04  86.12
# 24  86.78  86.24  85.88  85.58
# 25  86.94  86.36  85.94  85.92
# 26  86.40  86.28  85.84  85.78
# 27  87.18  85.78  85.86  85.68
# 28  87.22  86.28  85.84  85.92
# 29  87.20  86.20  85.82  85.96

# %%
sns.set()
fig,ax=plt.subplots(figsize=(15,10))
lines=locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)

for n in n_grams:
    y = table[n]
    label = "n_gram: "+str(n)
    lines[label],=ax.plot(x, y, label=label)
ax.legend(loc = 'best')
plt.title('Model hyperparameters:, n of n_gram')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)
plt.savefig('figure/n_gram_acc.jpg')

plt.show()

# %% [markdown]
# ### Compare Vocabulary size

# %%
vocab_sizes = [10002, 50000, 100000]
table = {}
train_loader, val_loader, test_loader = data_loader(1)
for i in vocab_sizes:
    print('vocabulary size:', i)
    train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, vocab_size = i )
    table[i] = val_history
# Out:
# vocabulary size: 10002
# Epoch: [1/5], Step: [101/625], Validation Acc: 65.22
# Epoch: [1/5], Step: [201/625], Validation Acc: 68.96
# Epoch: [1/5], Step: [301/625], Validation Acc: 73.6
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.86
# Epoch: [1/5], Step: [501/625], Validation Acc: 79.86
# Epoch: [1/5], Step: [601/625], Validation Acc: 81.94
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.56
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.84
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.26
# Epoch: [2/5], Step: [401/625], Validation Acc: 83.8
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.0
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.42
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.8
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.1
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.86
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.66
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.84
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.9
# Epoch: [4/5], Step: [101/625], Validation Acc: 87.16
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.82
# Epoch: [4/5], Step: [301/625], Validation Acc: 87.22
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.88
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.7
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.06
# Epoch: [5/5], Step: [101/625], Validation Acc: 87.28
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.84
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.94
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.06
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.26
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.88
# vocabulary size: 50000
# Epoch: [1/5], Step: [101/625], Validation Acc: 66.36
# Epoch: [1/5], Step: [201/625], Validation Acc: 69.74
# Epoch: [1/5], Step: [301/625], Validation Acc: 74.82
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.44
# Epoch: [1/5], Step: [501/625], Validation Acc: 80.08
# Epoch: [1/5], Step: [601/625], Validation Acc: 81.68
# Epoch: [2/5], Step: [101/625], Validation Acc: 82.86
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.62
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.38
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.88
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.66
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.88
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.66
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.06
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.54
# Epoch: [3/5], Step: [401/625], Validation Acc: 85.92
# Epoch: [3/5], Step: [501/625], Validation Acc: 85.08
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.42
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.74
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.62
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.62
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.94
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.94
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.12
# Epoch: [5/5], Step: [101/625], Validation Acc: 87.08
# Epoch: [5/5], Step: [201/625], Validation Acc: 87.46
# Epoch: [5/5], Step: [301/625], Validation Acc: 87.08
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.04
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.16
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.32
# vocabulary size: 100000
# Epoch: [1/5], Step: [101/625], Validation Acc: 60.74
# Epoch: [1/5], Step: [201/625], Validation Acc: 71.58
# Epoch: [1/5], Step: [301/625], Validation Acc: 74.92
# Epoch: [1/5], Step: [401/625], Validation Acc: 77.92
# Epoch: [1/5], Step: [501/625], Validation Acc: 80.6
# Epoch: [1/5], Step: [601/625], Validation Acc: 82.4
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.6
# Epoch: [2/5], Step: [201/625], Validation Acc: 84.34
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.52
# Epoch: [2/5], Step: [401/625], Validation Acc: 85.04
# Epoch: [2/5], Step: [501/625], Validation Acc: 84.82
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.42
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.56
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.88
# Epoch: [3/5], Step: [301/625], Validation Acc: 86.18
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.32
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.6
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.6
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.96
# Epoch: [4/5], Step: [201/625], Validation Acc: 87.04
# Epoch: [4/5], Step: [301/625], Validation Acc: 87.18
# Epoch: [4/5], Step: [401/625], Validation Acc: 87.06
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.76
# Epoch: [4/5], Step: [601/625], Validation Acc: 86.9
# Epoch: [5/5], Step: [101/625], Validation Acc: 87.28
# Epoch: [5/5], Step: [201/625], Validation Acc: 87.2
# Epoch: [5/5], Step: [301/625], Validation Acc: 87.24
# Epoch: [5/5], Step: [401/625], Validation Acc: 86.48
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.38
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.98

# %%
pkl.dump(table, open('accuracy/compare_vocab_size.p', "wb"))

# %%
print(pd.DataFrame(table))
# Out:
#     10002   50000   100000
# 0    65.22   66.36   60.74
# 1    68.96   69.74   71.58
# 2    73.60   74.82   74.92
# 3    78.86   78.44   77.92
# 4    79.86   80.08   80.60
# 5    81.94   81.68   82.40
# 6    83.56   82.86   83.60
# 7    83.84   83.62   84.34
# 8    84.26   84.38   84.52
# 9    83.80   84.88   85.04
# 10   85.00   85.66   84.82
# 11   85.42   85.88   85.42
# 12   85.80   85.66   85.56
# 13   86.10   86.06   85.88
# 14   85.86   85.54   86.18
# 15   86.66   85.92   86.32
# 16   86.84   85.08   86.60
# 17   86.90   86.42   86.60
# 18   87.16   86.74   86.96
# 19   86.82   86.62   87.04
# 20   87.22   86.62   87.18
# 21   86.88   86.94   87.06
# 22   86.70   86.94   86.76
# 23   87.06   87.12   86.90
# 24   87.28   87.08   87.28
# 25   86.84   87.46   87.20
# 26   86.94   87.08   87.24
# 27   87.06   87.04   86.48
# 28   87.26   87.16   87.38
# 29   86.88   87.32   86.98

# %%
sns.set()
fig,ax=plt.subplots(figsize=(15,10))
l=locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)

for n in vocab_sizes:
    y = table[n]
    label = "vocabulary size: "+str(n)
    l[label], = ax.plot(x, y, label=label)
    
ax.legend(loc = 'best')
plt.title('Model hyperparameters: vocabulary size')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)

plt.savefig('figure/vocab_acc.jpg')

plt.show()

# %% [markdown]
# ### Compare embedding size

# %%
embed_dims = [100, 200, 500]

table= {}
train_loader, val_loader, test_loader = data_loader(1)

for i in embed_dims:
    print('embedding dim:', i)
    train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, emb_dim = i )
    table[i] = val_history
# Out:
# embedding dim: 100
# Epoch: [1/5], Step: [101/625], Validation Acc: 55.06
# Epoch: [1/5], Step: [201/625], Validation Acc: 55.8
# Epoch: [1/5], Step: [301/625], Validation Acc: 62.96
# Epoch: [1/5], Step: [401/625], Validation Acc: 66.34
# Epoch: [1/5], Step: [501/625], Validation Acc: 69.48
# Epoch: [1/5], Step: [601/625], Validation Acc: 71.94
# Epoch: [2/5], Step: [101/625], Validation Acc: 75.28
# Epoch: [2/5], Step: [201/625], Validation Acc: 77.18
# Epoch: [2/5], Step: [301/625], Validation Acc: 78.98
# Epoch: [2/5], Step: [401/625], Validation Acc: 80.34
# Epoch: [2/5], Step: [501/625], Validation Acc: 81.46
# Epoch: [2/5], Step: [601/625], Validation Acc: 82.26
# Epoch: [3/5], Step: [101/625], Validation Acc: 83.06
# Epoch: [3/5], Step: [201/625], Validation Acc: 83.44
# Epoch: [3/5], Step: [301/625], Validation Acc: 83.64
# Epoch: [3/5], Step: [401/625], Validation Acc: 84.16
# Epoch: [3/5], Step: [501/625], Validation Acc: 84.44
# Epoch: [3/5], Step: [601/625], Validation Acc: 84.9
# Epoch: [4/5], Step: [101/625], Validation Acc: 85.04
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.2
# Epoch: [4/5], Step: [301/625], Validation Acc: 85.6
# Epoch: [4/5], Step: [401/625], Validation Acc: 85.82
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.18
# Epoch: [4/5], Step: [601/625], Validation Acc: 85.9
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.04
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.06
# Epoch: [5/5], Step: [301/625], Validation Acc: 85.8
# Epoch: [5/5], Step: [401/625], Validation Acc: 85.86
# Epoch: [5/5], Step: [501/625], Validation Acc: 86.4
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.54
# embedding dim: 200
# Epoch: [1/5], Step: [101/625], Validation Acc: 56.36
# Epoch: [1/5], Step: [201/625], Validation Acc: 60.06
# Epoch: [1/5], Step: [301/625], Validation Acc: 68.92
# Epoch: [1/5], Step: [401/625], Validation Acc: 73.44
# Epoch: [1/5], Step: [501/625], Validation Acc: 76.28
# Epoch: [1/5], Step: [601/625], Validation Acc: 77.92
# Epoch: [2/5], Step: [101/625], Validation Acc: 79.34
# Epoch: [2/5], Step: [201/625], Validation Acc: 80.98
# Epoch: [2/5], Step: [301/625], Validation Acc: 81.72
# Epoch: [2/5], Step: [401/625], Validation Acc: 82.62
# Epoch: [2/5], Step: [501/625], Validation Acc: 83.58
# Epoch: [2/5], Step: [601/625], Validation Acc: 83.5
# Epoch: [3/5], Step: [101/625], Validation Acc: 84.48
# Epoch: [3/5], Step: [201/625], Validation Acc: 84.4
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.1
# Epoch: [3/5], Step: [401/625], Validation Acc: 85.34
# Epoch: [3/5], Step: [501/625], Validation Acc: 85.4
# Epoch: [3/5], Step: [601/625], Validation Acc: 85.82
# Epoch: [4/5], Step: [101/625], Validation Acc: 85.82
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.38
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.58
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.64
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.66
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.16
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.1
# Epoch: [5/5], Step: [201/625], Validation Acc: 87.14
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.84
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.24
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.2
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.22
# embedding dim: 500
# Epoch: [1/5], Step: [101/625], Validation Acc: 62.0
# Epoch: [1/5], Step: [201/625], Validation Acc: 72.04
# Epoch: [1/5], Step: [301/625], Validation Acc: 75.92
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.78
# Epoch: [1/5], Step: [501/625], Validation Acc: 81.02
# Epoch: [1/5], Step: [601/625], Validation Acc: 81.62
# Epoch: [2/5], Step: [101/625], Validation Acc: 82.5
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.38
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.34
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.42
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.46
# Epoch: [2/5], Step: [601/625], Validation Acc: 84.52
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.62
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.24
# Epoch: [3/5], Step: [301/625], Validation Acc: 86.2
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.62
# Epoch: [3/5], Step: [501/625], Validation Acc: 85.48
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.56
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.62
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.6
# Epoch: [4/5], Step: [301/625], Validation Acc: 87.08
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.92
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.88
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.18
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.7
# Epoch: [5/5], Step: [201/625], Validation Acc: 87.24
# Epoch: [5/5], Step: [301/625], Validation Acc: 87.12
# Epoch: [5/5], Step: [401/625], Validation Acc: 86.24
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.22
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.02

# %%
pkl.dump(table, open('accuracy/compare_emb_dim.p', "wb"))

# %%
print(pd.DataFrame(table))
# Out:
#       100    200    500
# 0   55.06  56.36  62.00
# 1   55.80  60.06  72.04
# 2   62.96  68.92  75.92
# 3   66.34  73.44  78.78
# 4   69.48  76.28  81.02
# 5   71.94  77.92  81.62
# 6   75.28  79.34  82.50
# 7   77.18  80.98  83.38
# 8   78.98  81.72  84.34
# 9   80.34  82.62  84.42
# 10  81.46  83.58  85.46
# 11  82.26  83.50  84.52
# 12  83.06  84.48  85.62
# 13  83.44  84.40  86.24
# 14  83.64  85.10  86.20
# 15  84.16  85.34  86.62
# 16  84.44  85.40  85.48
# 17  84.90  85.82  86.56
# 18  85.04  85.82  86.62
# 19  85.20  86.38  86.60
# 20  85.60  86.58  87.08
# 21  85.82  86.64  86.92
# 22  86.18  86.66  86.88
# 23  85.90  87.16  87.18
# 24  86.04  86.10  86.70
# 25  86.06  87.14  87.24
# 26  85.80  86.84  87.12
# 27  85.86  87.24  86.24
# 28  86.40  87.20  87.22
# 29  86.54  87.22  87.02

# %%
sns.set()
fig, ax = plt.subplots(figsize=(15,10))
l=locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)
for n in embed_dims:
    y = table[n]
    label = "embed_dim: "+str(n)
    l[label],=ax.plot(x, y, label=label)
    
ax.legend(loc = 'best')
plt.title('Model hyperparameters: embedding size')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)
plt.savefig('figure/emb_acc.jpg')

plt.show()

# %% [markdown]
# ### Comapre Optimizers

# %%
optimizers = ['Adam', 'SGD']
train_loader, val_loader, test_loader = data_loader(1)
table= {}
momentums = [0.1, 0.5, 0.9]
for opt in optimizers:
    print('optimizer:', opt)
    if opt == 'SGD':
        for mon in momentums:
            train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, optimizer_name = opt, momentum = mon )
            name = opt+'_'+str(mon)
            table[name] = val_history     
    else:
        train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, optimizer_name = opt)
        table[opt] = val_history
# Out:
# optimizer: Adam
# Epoch: [1/5], Step: [101/625], Validation Acc: 58.24
# Epoch: [1/5], Step: [201/625], Validation Acc: 69.3
# Epoch: [1/5], Step: [301/625], Validation Acc: 74.92
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.46
# Epoch: [1/5], Step: [501/625], Validation Acc: 81.06
# Epoch: [1/5], Step: [601/625], Validation Acc: 82.0
# Epoch: [2/5], Step: [101/625], Validation Acc: 82.82
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.98
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.22
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.62
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.2
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.7
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.72
# Epoch: [3/5], Step: [201/625], Validation Acc: 86.14
# Epoch: [3/5], Step: [301/625], Validation Acc: 86.26
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.62
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.42
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.7
# Epoch: [4/5], Step: [101/625], Validation Acc: 87.02
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.8
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.96
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.84
# Epoch: [4/5], Step: [501/625], Validation Acc: 87.0
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.02
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.96
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.76
# Epoch: [5/5], Step: [301/625], Validation Acc: 87.1
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.02
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.14
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.88
# optimizer: SGD
# Epoch: [1/5], Step: [101/625], Validation Acc: 49.08
# Epoch: [1/5], Step: [201/625], Validation Acc: 49.3
# Epoch: [1/5], Step: [301/625], Validation Acc: 49.5
# Epoch: [1/5], Step: [401/625], Validation Acc: 50.2
# Epoch: [1/5], Step: [501/625], Validation Acc: 51.02
# Epoch: [1/5], Step: [601/625], Validation Acc: 51.8
# Epoch: [2/5], Step: [101/625], Validation Acc: 53.36
# Epoch: [2/5], Step: [201/625], Validation Acc: 53.66
# Epoch: [2/5], Step: [301/625], Validation Acc: 54.7
# Epoch: [2/5], Step: [401/625], Validation Acc: 55.54
# Epoch: [2/5], Step: [501/625], Validation Acc: 56.12
# Epoch: [2/5], Step: [601/625], Validation Acc: 55.88
# Epoch: [3/5], Step: [101/625], Validation Acc: 57.02
# Epoch: [3/5], Step: [201/625], Validation Acc: 57.64
# Epoch: [3/5], Step: [301/625], Validation Acc: 57.26
# Epoch: [3/5], Step: [401/625], Validation Acc: 57.92
# Epoch: [3/5], Step: [501/625], Validation Acc: 58.36
# Epoch: [3/5], Step: [601/625], Validation Acc: 58.38
# Epoch: [4/5], Step: [101/625], Validation Acc: 58.94
# Epoch: [4/5], Step: [201/625], Validation Acc: 58.96
# Epoch: [4/5], Step: [301/625], Validation Acc: 59.96
# Epoch: [4/5], Step: [401/625], Validation Acc: 59.58
# Epoch: [4/5], Step: [501/625], Validation Acc: 59.96
# Epoch: [4/5], Step: [601/625], Validation Acc: 60.22
# Epoch: [5/5], Step: [101/625], Validation Acc: 60.52
# Epoch: [5/5], Step: [201/625], Validation Acc: 61.3
# Epoch: [5/5], Step: [301/625], Validation Acc: 61.24
# Epoch: [5/5], Step: [401/625], Validation Acc: 61.7
# Epoch: [5/5], Step: [501/625], Validation Acc: 61.7
# Epoch: [5/5], Step: [601/625], Validation Acc: 61.22
# Epoch: [1/5], Step: [101/625], Validation Acc: 52.66
# Epoch: [1/5], Step: [201/625], Validation Acc: 53.6
# Epoch: [1/5], Step: [301/625], Validation Acc: 54.92
# Epoch: [1/5], Step: [401/625], Validation Acc: 55.06
# Epoch: [1/5], Step: [501/625], Validation Acc: 56.12
# Epoch: [1/5], Step: [601/625], Validation Acc: 58.48
# Epoch: [2/5], Step: [101/625], Validation Acc: 59.16
# Epoch: [2/5], Step: [201/625], Validation Acc: 60.12
# Epoch: [2/5], Step: [301/625], Validation Acc: 60.16
# Epoch: [2/5], Step: [401/625], Validation Acc: 60.84
# Epoch: [2/5], Step: [501/625], Validation Acc: 62.12
# Epoch: [2/5], Step: [601/625], Validation Acc: 61.14
# Epoch: [3/5], Step: [101/625], Validation Acc: 62.32
# Epoch: [3/5], Step: [201/625], Validation Acc: 62.28
# Epoch: [3/5], Step: [301/625], Validation Acc: 62.92
# Epoch: [3/5], Step: [401/625], Validation Acc: 62.72
# Epoch: [3/5], Step: [501/625], Validation Acc: 62.1
# Epoch: [3/5], Step: [601/625], Validation Acc: 63.28
# Epoch: [4/5], Step: [101/625], Validation Acc: 63.52
# Epoch: [4/5], Step: [201/625], Validation Acc: 63.62
# Epoch: [4/5], Step: [301/625], Validation Acc: 63.84
# Epoch: [4/5], Step: [401/625], Validation Acc: 63.68
# Epoch: [4/5], Step: [501/625], Validation Acc: 63.74
# Epoch: [4/5], Step: [601/625], Validation Acc: 63.98
# Epoch: [5/5], Step: [101/625], Validation Acc: 64.34
# Epoch: [5/5], Step: [201/625], Validation Acc: 64.2
# Epoch: [5/5], Step: [301/625], Validation Acc: 64.14
# Epoch: [5/5], Step: [401/625], Validation Acc: 64.46
# Epoch: [5/5], Step: [501/625], Validation Acc: 64.58
# Epoch: [5/5], Step: [601/625], Validation Acc: 64.94
# Epoch: [1/5], Step: [101/625], Validation Acc: 56.14
# Epoch: [1/5], Step: [201/625], Validation Acc: 58.52
# Epoch: [1/5], Step: [301/625], Validation Acc: 62.26
# Epoch: [1/5], Step: [401/625], Validation Acc: 63.68
# Epoch: [1/5], Step: [501/625], Validation Acc: 64.7
# Epoch: [1/5], Step: [601/625], Validation Acc: 64.26
# Epoch: [2/5], Step: [101/625], Validation Acc: 66.32
# Epoch: [2/5], Step: [201/625], Validation Acc: 65.16
# Epoch: [2/5], Step: [301/625], Validation Acc: 66.72
# Epoch: [2/5], Step: [401/625], Validation Acc: 67.0
# Epoch: [2/5], Step: [501/625], Validation Acc: 65.68
# Epoch: [2/5], Step: [601/625], Validation Acc: 67.66
# Epoch: [3/5], Step: [101/625], Validation Acc: 67.86
# Epoch: [3/5], Step: [201/625], Validation Acc: 67.64
# Epoch: [3/5], Step: [301/625], Validation Acc: 66.96
# Epoch: [3/5], Step: [401/625], Validation Acc: 67.96
# Epoch: [3/5], Step: [501/625], Validation Acc: 68.72
# Epoch: [3/5], Step: [601/625], Validation Acc: 68.62
# Epoch: [4/5], Step: [101/625], Validation Acc: 68.78
# Epoch: [4/5], Step: [201/625], Validation Acc: 68.9
# Epoch: [4/5], Step: [301/625], Validation Acc: 69.46
# Epoch: [4/5], Step: [401/625], Validation Acc: 69.52
# Epoch: [4/5], Step: [501/625], Validation Acc: 69.5
# Epoch: [4/5], Step: [601/625], Validation Acc: 69.6
# Epoch: [5/5], Step: [101/625], Validation Acc: 69.78
# Epoch: [5/5], Step: [201/625], Validation Acc: 69.84
# Epoch: [5/5], Step: [301/625], Validation Acc: 69.96
# Epoch: [5/5], Step: [401/625], Validation Acc: 70.16
# Epoch: [5/5], Step: [501/625], Validation Acc: 70.22
# Epoch: [5/5], Step: [601/625], Validation Acc: 70.38

# %%
print(pd.DataFrame(table))
# Out:
#      Adam  SGD_0.1  SGD_0.5  SGD_0.9
# 0   58.24    49.08    52.66    56.14
# 1   69.30    49.30    53.60    58.52
# 2   74.92    49.50    54.92    62.26
# 3   78.46    50.20    55.06    63.68
# 4   81.06    51.02    56.12    64.70
# 5   82.00    51.80    58.48    64.26
# 6   82.82    53.36    59.16    66.32
# 7   83.98    53.66    60.12    65.16
# 8   84.22    54.70    60.16    66.72
# 9   84.62    55.54    60.84    67.00
# 10  85.20    56.12    62.12    65.68
# 11  85.70    55.88    61.14    67.66
# 12  85.72    57.02    62.32    67.86
# 13  86.14    57.64    62.28    67.64
# 14  86.26    57.26    62.92    66.96
# 15  86.62    57.92    62.72    67.96
# 16  86.42    58.36    62.10    68.72
# 17  86.70    58.38    63.28    68.62
# 18  87.02    58.94    63.52    68.78
# 19  86.80    58.96    63.62    68.90
# 20  86.96    59.96    63.84    69.46
# 21  86.84    59.58    63.68    69.52
# 22  87.00    59.96    63.74    69.50
# 23  87.02    60.22    63.98    69.60
# 24  86.96    60.52    64.34    69.78
# 25  86.76    61.30    64.20    69.84
# 26  87.10    61.24    64.14    69.96
# 27  87.02    61.70    64.46    70.16
# 28  87.14    61.70    64.58    70.22
# 29  86.88    61.22    64.94    70.38

# %%
pkl.dump(table, open('accuracy/compare_optimizer.p', "wb"))

# %%
sns.set()
fig, ax = plt.subplots(figsize=(15,10))
l = locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)
for opt in table.keys():
    y = table[opt]
    label = 'optimizer:'+str(opt)
    l[label], = ax.plot(x, y, label = label)
    
ax.legend(loc = 'best')
plt.title('Optimization hyperparameters: optimizer')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(40,100)
plt.savefig('figure/opt_acc.jpg')

plt.show()

# %% [markdown]
# ### Compare Learning Rate

# %%
learning_rates = [0.01, 0.05, 0.001, 0.0001]
annealing = [True, False]

train_loader, val_loader, test_loader = data_loader(1)
table= {}
for lr in learning_rates:
    for an_lr in annealing:
        print('learning rate:', lr, 'annealing_learing:', an_lr)
        train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, learning_rate = lr, annealing_learing = an_lr )
        name = str(lr)+','+str(an_lr)
        table[name] = val_history
# Out:
# learning rate: 0.01 annealing_learing: True
# Epoch: [1/5], Step: [101/625], Validation Acc: 79.62
# Epoch: [1/5], Step: [201/625], Validation Acc: 83.36
# Epoch: [1/5], Step: [301/625], Validation Acc: 84.44
# Epoch: [1/5], Step: [401/625], Validation Acc: 84.24
# Epoch: [1/5], Step: [501/625], Validation Acc: 83.62
# Epoch: [1/5], Step: [601/625], Validation Acc: 85.78
# Epoch: [2/5], Step: [101/625], Validation Acc: 86.34
# Epoch: [2/5], Step: [201/625], Validation Acc: 85.26
# Epoch: [2/5], Step: [301/625], Validation Acc: 86.2
# Epoch: [2/5], Step: [401/625], Validation Acc: 85.86
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.42
# Epoch: [2/5], Step: [601/625], Validation Acc: 84.44
# Epoch: [3/5], Step: [101/625], Validation Acc: 84.56
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.24
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.34
# Epoch: [3/5], Step: [401/625], Validation Acc: 85.34
# Epoch: [3/5], Step: [501/625], Validation Acc: 84.84
# Epoch: [3/5], Step: [601/625], Validation Acc: 85.48
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.04
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.94
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.0
# Epoch: [4/5], Step: [401/625], Validation Acc: 85.76
# Epoch: [4/5], Step: [501/625], Validation Acc: 85.84
# Epoch: [4/5], Step: [601/625], Validation Acc: 85.82
# Epoch: [5/5], Step: [101/625], Validation Acc: 85.8
# Epoch: [5/5], Step: [201/625], Validation Acc: 85.98
# Epoch: [5/5], Step: [301/625], Validation Acc: 85.88
# Epoch: [5/5], Step: [401/625], Validation Acc: 85.96
# Epoch: [5/5], Step: [501/625], Validation Acc: 85.94
# Epoch: [5/5], Step: [601/625], Validation Acc: 85.68
# learning rate: 0.01 annealing_learing: False
# Epoch: [1/5], Step: [101/625], Validation Acc: 81.3
# Epoch: [1/5], Step: [201/625], Validation Acc: 84.22
# Epoch: [1/5], Step: [301/625], Validation Acc: 84.58
# Epoch: [1/5], Step: [401/625], Validation Acc: 86.06
# Epoch: [1/5], Step: [501/625], Validation Acc: 84.4
# Epoch: [1/5], Step: [601/625], Validation Acc: 86.52
# Epoch: [2/5], Step: [101/625], Validation Acc: 86.54
# Epoch: [2/5], Step: [201/625], Validation Acc: 86.38
# Epoch: [2/5], Step: [301/625], Validation Acc: 85.48
# Epoch: [2/5], Step: [401/625], Validation Acc: 86.1
# Epoch: [2/5], Step: [501/625], Validation Acc: 86.22
# Epoch: [2/5], Step: [601/625], Validation Acc: 86.44
# Epoch: [3/5], Step: [101/625], Validation Acc: 86.22
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.78
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.98
# Epoch: [3/5], Step: [401/625], Validation Acc: 84.1
# Epoch: [3/5], Step: [501/625], Validation Acc: 85.48
# Epoch: [3/5], Step: [601/625], Validation Acc: 85.36
# Epoch: [4/5], Step: [101/625], Validation Acc: 85.9
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.02
# Epoch: [4/5], Step: [301/625], Validation Acc: 84.94
# Epoch: [4/5], Step: [401/625], Validation Acc: 84.32
# Epoch: [4/5], Step: [501/625], Validation Acc: 84.92
# Epoch: [4/5], Step: [601/625], Validation Acc: 85.08
# Epoch: [5/5], Step: [101/625], Validation Acc: 84.9
# Epoch: [5/5], Step: [201/625], Validation Acc: 84.68
# Epoch: [5/5], Step: [301/625], Validation Acc: 84.98
# Epoch: [5/5], Step: [401/625], Validation Acc: 83.02
# Epoch: [5/5], Step: [501/625], Validation Acc: 84.52
# Epoch: [5/5], Step: [601/625], Validation Acc: 83.4
# learning rate: 0.05 annealing_learing: True
# Epoch: [1/5], Step: [101/625], Validation Acc: 79.96
# Epoch: [1/5], Step: [201/625], Validation Acc: 77.52
# Epoch: [1/5], Step: [301/625], Validation Acc: 83.42
# Epoch: [1/5], Step: [401/625], Validation Acc: 84.1
# Epoch: [1/5], Step: [501/625], Validation Acc: 81.14
# Epoch: [1/5], Step: [601/625], Validation Acc: 85.7
# Epoch: [2/5], Step: [101/625], Validation Acc: 84.84
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.92
# Epoch: [2/5], Step: [301/625], Validation Acc: 80.62
# Epoch: [2/5], Step: [401/625], Validation Acc: 83.56
# Epoch: [2/5], Step: [501/625], Validation Acc: 84.8
# Epoch: [2/5], Step: [601/625], Validation Acc: 83.82
# Epoch: [3/5], Step: [101/625], Validation Acc: 81.64
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.16
# Epoch: [3/5], Step: [301/625], Validation Acc: 82.66
# Epoch: [3/5], Step: [401/625], Validation Acc: 83.86
# Epoch: [3/5], Step: [501/625], Validation Acc: 83.92
# Epoch: [3/5], Step: [601/625], Validation Acc: 83.1
# Epoch: [4/5], Step: [101/625], Validation Acc: 85.14
# Epoch: [4/5], Step: [201/625], Validation Acc: 85.24
# Epoch: [4/5], Step: [301/625], Validation Acc: 85.14
# Epoch: [4/5], Step: [401/625], Validation Acc: 85.26
# Epoch: [4/5], Step: [501/625], Validation Acc: 85.28
# Epoch: [4/5], Step: [601/625], Validation Acc: 85.34
# Epoch: [5/5], Step: [101/625], Validation Acc: 85.4
# Epoch: [5/5], Step: [201/625], Validation Acc: 84.78
# Epoch: [5/5], Step: [301/625], Validation Acc: 85.14
# Epoch: [5/5], Step: [401/625], Validation Acc: 85.08
# Epoch: [5/5], Step: [501/625], Validation Acc: 85.02
# Epoch: [5/5], Step: [601/625], Validation Acc: 84.78
# learning rate: 0.05 annealing_learing: False
# Epoch: [1/5], Step: [101/625], Validation Acc: 80.8
# Epoch: [1/5], Step: [201/625], Validation Acc: 80.46
# Epoch: [1/5], Step: [301/625], Validation Acc: 81.16
# Epoch: [1/5], Step: [401/625], Validation Acc: 83.0
# Epoch: [1/5], Step: [501/625], Validation Acc: 84.86
# Epoch: [1/5], Step: [601/625], Validation Acc: 81.54
# Epoch: [2/5], Step: [101/625], Validation Acc: 84.78
# Epoch: [2/5], Step: [201/625], Validation Acc: 84.5
# Epoch: [2/5], Step: [301/625], Validation Acc: 80.98
# Epoch: [2/5], Step: [401/625], Validation Acc: 83.8
# Epoch: [2/5], Step: [501/625], Validation Acc: 79.58
# Epoch: [2/5], Step: [601/625], Validation Acc: 83.84
# Epoch: [3/5], Step: [101/625], Validation Acc: 83.96
# Epoch: [3/5], Step: [201/625], Validation Acc: 83.54
# Epoch: [3/5], Step: [301/625], Validation Acc: 82.96
# Epoch: [3/5], Step: [401/625], Validation Acc: 84.08
# Epoch: [3/5], Step: [501/625], Validation Acc: 82.28
# Epoch: [3/5], Step: [601/625], Validation Acc: 83.76
# Epoch: [4/5], Step: [101/625], Validation Acc: 83.56
# Epoch: [4/5], Step: [201/625], Validation Acc: 82.86
# Epoch: [4/5], Step: [301/625], Validation Acc: 82.78
# Epoch: [4/5], Step: [401/625], Validation Acc: 83.4
# Epoch: [4/5], Step: [501/625], Validation Acc: 81.78
# Epoch: [4/5], Step: [601/625], Validation Acc: 82.1
# Epoch: [5/5], Step: [101/625], Validation Acc: 83.72
# Epoch: [5/5], Step: [201/625], Validation Acc: 83.36
# Epoch: [5/5], Step: [301/625], Validation Acc: 79.92
# Epoch: [5/5], Step: [401/625], Validation Acc: 83.22
# Epoch: [5/5], Step: [501/625], Validation Acc: 80.34
# Epoch: [5/5], Step: [601/625], Validation Acc: 80.22
# learning rate: 0.001 annealing_learing: True
# Epoch: [1/5], Step: [101/625], Validation Acc: 67.08
# Epoch: [1/5], Step: [201/625], Validation Acc: 71.88
# Epoch: [1/5], Step: [301/625], Validation Acc: 76.14
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.78
# Epoch: [1/5], Step: [501/625], Validation Acc: 81.42
# Epoch: [1/5], Step: [601/625], Validation Acc: 82.22
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.22
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.18
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.74
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.92
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.42
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.68
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.8
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.88
# Epoch: [3/5], Step: [301/625], Validation Acc: 86.14
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.66
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.48
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.56
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.62
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.6
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.68
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.8
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.62
# Epoch: [4/5], Step: [601/625], Validation Acc: 86.88
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.76
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.74
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.78
# Epoch: [5/5], Step: [401/625], Validation Acc: 86.88
# Epoch: [5/5], Step: [501/625], Validation Acc: 86.72
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.72
# learning rate: 0.001 annealing_learing: False
# Epoch: [1/5], Step: [101/625], Validation Acc: 63.38
# Epoch: [1/5], Step: [201/625], Validation Acc: 69.26
# Epoch: [1/5], Step: [301/625], Validation Acc: 75.46
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.26
# Epoch: [1/5], Step: [501/625], Validation Acc: 80.12
# Epoch: [1/5], Step: [601/625], Validation Acc: 80.9
# Epoch: [2/5], Step: [101/625], Validation Acc: 82.92
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.68
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.36
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.66
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.08
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.4
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.84
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.64
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.94
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.2
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.76
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.92
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.28
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.72
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.52
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.66
# Epoch: [4/5], Step: [501/625], Validation Acc: 87.04
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.22
# Epoch: [5/5], Step: [101/625], Validation Acc: 86.72
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.9
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.94
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.04
# Epoch: [5/5], Step: [501/625], Validation Acc: 86.8
# Epoch: [5/5], Step: [601/625], Validation Acc: 87.08
# learning rate: 0.0001 annealing_learing: True
# Epoch: [1/5], Step: [101/625], Validation Acc: 54.02
# Epoch: [1/5], Step: [201/625], Validation Acc: 55.64
# Epoch: [1/5], Step: [301/625], Validation Acc: 56.86
# Epoch: [1/5], Step: [401/625], Validation Acc: 57.52
# Epoch: [1/5], Step: [501/625], Validation Acc: 57.78
# Epoch: [1/5], Step: [601/625], Validation Acc: 61.56
# Epoch: [2/5], Step: [101/625], Validation Acc: 63.64
# Epoch: [2/5], Step: [201/625], Validation Acc: 65.08
# Epoch: [2/5], Step: [301/625], Validation Acc: 65.08
# Epoch: [2/5], Step: [401/625], Validation Acc: 66.6
# Epoch: [2/5], Step: [501/625], Validation Acc: 67.58
# Epoch: [2/5], Step: [601/625], Validation Acc: 67.7
# Epoch: [3/5], Step: [101/625], Validation Acc: 68.36
# Epoch: [3/5], Step: [201/625], Validation Acc: 68.84
# Epoch: [3/5], Step: [301/625], Validation Acc: 69.38
# Epoch: [3/5], Step: [401/625], Validation Acc: 70.56
# Epoch: [3/5], Step: [501/625], Validation Acc: 70.82
# Epoch: [3/5], Step: [601/625], Validation Acc: 71.6
# Epoch: [4/5], Step: [101/625], Validation Acc: 71.9
# Epoch: [4/5], Step: [201/625], Validation Acc: 71.88
# Epoch: [4/5], Step: [301/625], Validation Acc: 71.96
# Epoch: [4/5], Step: [401/625], Validation Acc: 71.94
# Epoch: [4/5], Step: [501/625], Validation Acc: 72.1
# Epoch: [4/5], Step: [601/625], Validation Acc: 72.02
# Epoch: [5/5], Step: [101/625], Validation Acc: 72.22
# Epoch: [5/5], Step: [201/625], Validation Acc: 72.16
# Epoch: [5/5], Step: [301/625], Validation Acc: 72.24
# Epoch: [5/5], Step: [401/625], Validation Acc: 72.26
# Epoch: [5/5], Step: [501/625], Validation Acc: 72.26
# Epoch: [5/5], Step: [601/625], Validation Acc: 72.44
# learning rate: 0.0001 annealing_learing: False
# Epoch: [1/5], Step: [101/625], Validation Acc: 54.12
# Epoch: [1/5], Step: [201/625], Validation Acc: 56.82
# Epoch: [1/5], Step: [301/625], Validation Acc: 58.24
# Epoch: [1/5], Step: [401/625], Validation Acc: 60.64
# Epoch: [1/5], Step: [501/625], Validation Acc: 63.56
# Epoch: [1/5], Step: [601/625], Validation Acc: 65.62
# Epoch: [2/5], Step: [101/625], Validation Acc: 67.4
# Epoch: [2/5], Step: [201/625], Validation Acc: 67.62
# Epoch: [2/5], Step: [301/625], Validation Acc: 68.06
# Epoch: [2/5], Step: [401/625], Validation Acc: 68.74
# Epoch: [2/5], Step: [501/625], Validation Acc: 69.24
# Epoch: [2/5], Step: [601/625], Validation Acc: 69.5
# Epoch: [3/5], Step: [101/625], Validation Acc: 69.04
# Epoch: [3/5], Step: [201/625], Validation Acc: 70.52
# Epoch: [3/5], Step: [301/625], Validation Acc: 71.02
# Epoch: [3/5], Step: [401/625], Validation Acc: 71.28
# Epoch: [3/5], Step: [501/625], Validation Acc: 71.58
# Epoch: [3/5], Step: [601/625], Validation Acc: 72.02
# Epoch: [4/5], Step: [101/625], Validation Acc: 72.54
# Epoch: [4/5], Step: [201/625], Validation Acc: 73.08
# Epoch: [4/5], Step: [301/625], Validation Acc: 73.46
# Epoch: [4/5], Step: [401/625], Validation Acc: 73.82
# Epoch: [4/5], Step: [501/625], Validation Acc: 73.98
# Epoch: [4/5], Step: [601/625], Validation Acc: 74.3
# Epoch: [5/5], Step: [101/625], Validation Acc: 74.84
# Epoch: [5/5], Step: [201/625], Validation Acc: 75.0
# Epoch: [5/5], Step: [301/625], Validation Acc: 75.66
# Epoch: [5/5], Step: [401/625], Validation Acc: 75.54
# Epoch: [5/5], Step: [501/625], Validation Acc: 76.14
# Epoch: [5/5], Step: [601/625], Validation Acc: 76.52

# %%
print(pd.DataFrame(table))
# Out:
#     0.0001,False  0.0001,True  0.001,False  0.001,True  0.01,False  0.01,True  \
# 0          54.12        54.02        63.38       67.08       81.30      79.62
# 1          56.82        55.64        69.26       71.88       84.22      83.36
# 2          58.24        56.86        75.46       76.14       84.58      84.44
# 3          60.64        57.52        78.26       78.78       86.06      84.24
# 4          63.56        57.78        80.12       81.42       84.40      83.62
# 5          65.62        61.56        80.90       82.22       86.52      85.78
# 6          67.40        63.64        82.92       83.22       86.54      86.34
# 7          67.62        65.08        83.68       83.18       86.38      85.26
# 8          68.06        65.08        84.36       84.74       85.48      86.20
# 9          68.74        66.60        84.66       84.92       86.10      85.86
# 10         69.24        67.58        85.08       85.42       86.22      85.42
# 11         69.50        67.70        85.40       85.68       86.44      84.44
# 12         69.04        68.36        85.84       85.80       86.22      84.56
# 13         70.52        68.84        85.64       85.88       85.78      85.24
# 14         71.02        69.38        85.94       86.14       85.98      85.34
# 15         71.28        70.56        86.20       86.66       84.10      85.34
# 16         71.58        70.82        86.76       86.48       85.48      84.84
# 17         72.02        71.60        86.92       86.56       85.36      85.48
# 18         72.54        71.90        86.28       86.62       85.90      86.04
# 19         73.08        71.88        86.72       86.60       85.02      85.94
# 20         73.46        71.96        86.52       86.68       84.94      86.00
# 21         73.82        71.94        86.66       86.80       84.32      85.76
# 22         73.98        72.10        87.04       86.62       84.92      85.84
# 23         74.30        72.02        87.22       86.88       85.08      85.82
# 24         74.84        72.22        86.72       86.76       84.90      85.80
# 25         75.00        72.16        86.90       86.74       84.68      85.98
# 26         75.66        72.24        86.94       86.78       84.98      85.88
# 27         75.54        72.26        87.04       86.88       83.02      85.96
# 28         76.14        72.26        86.80       86.72       84.52      85.94
# 29         76.52        72.44        87.08       86.72       83.40      85.68
#
#     0.05,False  0.05,True
# 0        80.80      79.96
# 1        80.46      77.52
# 2        81.16      83.42
# 3        83.00      84.10
# 4        84.86      81.14
# 5        81.54      85.70
# 6        84.78      84.84
# 7        84.50      83.92
# 8        80.98      80.62
# 9        83.80      83.56
# 10       79.58      84.80
# 11       83.84      83.82
# 12       83.96      81.64
# 13       83.54      85.16
# 14       82.96      82.66
# 15       84.08      83.86
# 16       82.28      83.92
# 17       83.76      83.10
# 18       83.56      85.14
# 19       82.86      85.24
# 20       82.78      85.14
# 21       83.40      85.26
# 22       81.78      85.28
# 23       82.10      85.34
# 24       83.72      85.40
# 25       83.36      84.78
# 26       79.92      85.14
# 27       83.22      85.08
# 28       80.34      85.02
# 29       80.22      84.78

# %%
pkl.dump(table, open('accuracy/compare_lr.p', "wb"))

# %%
sns.set()

fig, ax = plt.subplots(figsize=(15,10))
l = locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)
for i in table.keys():
    y = table[i]
    label = 'learning rate:'+i.split(',')[0]+', annealing lr:'+i.split(',')[1]
    l[label],=ax.plot(x, y, label = label)
    
ax.legend(loc = 'best')
plt.title('Optimization hyperparameters: learning rate')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)
plt.savefig('figure/lr_acc.jpg')

plt.show()

# %% [markdown]
# ### Plot training curves for the best model

# %%
import pickle as pkl
table= {}
train_loader, val_loader, test_loader = data_loader(1)

emb_dim = 500
model = BagOfWords(10002, emb_dim)
learning_rate = 0.001
num_epochs = 5 # number epoch to train

# Criterion and Optimizer
criterion = torch.nn.CrossEntropyLoss()  
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

val_history = []
train_history = []
for epoch in range(num_epochs):
    for i, (data, lengths, labels) in enumerate(train_loader):
        model.train()
        data_batch, length_batch, label_batch = data, lengths, labels
        optimizer.zero_grad()
        outputs = model(data_batch, length_batch)
        loss = criterion(outputs, label_batch)
        loss.backward()
        optimizer.step()
        # validate every 100 iterations
        if i > 0 and i % 100 == 0:
            # validate
            val_acc = test_model(val_loader, model)
            train_acc = test_model(train_loader, model)
            val_history.append(val_acc)
            train_history.append(train_acc)
            print('Epoch: [{}/{}], Step: [{}/{}], Validation Acc: {}'.format( 
                       epoch+1, num_epochs, i+1, len(train_loader), val_acc))
test_acc = test_model(test_loader, model)

table['val_history'] = val_history
table['train_history'] = train_history
table['test_acc'] = test_acc
# Out:
# Epoch: [1/5], Step: [101/625], Validation Acc: 62.96
# Epoch: [1/5], Step: [201/625], Validation Acc: 70.72
# Epoch: [1/5], Step: [301/625], Validation Acc: 75.9
# Epoch: [1/5], Step: [401/625], Validation Acc: 78.94
# Epoch: [1/5], Step: [501/625], Validation Acc: 80.74
# Epoch: [1/5], Step: [601/625], Validation Acc: 82.1
# Epoch: [2/5], Step: [101/625], Validation Acc: 83.42
# Epoch: [2/5], Step: [201/625], Validation Acc: 83.86
# Epoch: [2/5], Step: [301/625], Validation Acc: 84.08
# Epoch: [2/5], Step: [401/625], Validation Acc: 84.68
# Epoch: [2/5], Step: [501/625], Validation Acc: 85.04
# Epoch: [2/5], Step: [601/625], Validation Acc: 85.3
# Epoch: [3/5], Step: [101/625], Validation Acc: 85.92
# Epoch: [3/5], Step: [201/625], Validation Acc: 85.88
# Epoch: [3/5], Step: [301/625], Validation Acc: 85.96
# Epoch: [3/5], Step: [401/625], Validation Acc: 86.24
# Epoch: [3/5], Step: [501/625], Validation Acc: 86.56
# Epoch: [3/5], Step: [601/625], Validation Acc: 86.7
# Epoch: [4/5], Step: [101/625], Validation Acc: 86.82
# Epoch: [4/5], Step: [201/625], Validation Acc: 86.84
# Epoch: [4/5], Step: [301/625], Validation Acc: 86.96
# Epoch: [4/5], Step: [401/625], Validation Acc: 86.74
# Epoch: [4/5], Step: [501/625], Validation Acc: 86.92
# Epoch: [4/5], Step: [601/625], Validation Acc: 87.18
# Epoch: [5/5], Step: [101/625], Validation Acc: 87.02
# Epoch: [5/5], Step: [201/625], Validation Acc: 86.98
# Epoch: [5/5], Step: [301/625], Validation Acc: 86.84
# Epoch: [5/5], Step: [401/625], Validation Acc: 87.14
# Epoch: [5/5], Step: [501/625], Validation Acc: 87.14
# Epoch: [5/5], Step: [601/625], Validation Acc: 86.62

# %%
pkl.dump(table, open('accuracy/acc_history.p', 'wb'))
pkl.dump(model, open('final_model.p', 'wb'))

# %%
print(pd.DataFrame(table))
# Out:
#     test_acc  train_history  val_history
# 0       85.5         63.355        62.96
# 1       85.5         71.550        70.72
# 2       85.5         77.740        75.90
# 3       85.5         80.885        78.94
# 4       85.5         82.965        80.74
# 5       85.5         84.215        82.10
# 6       85.5         85.800        83.42
# 7       85.5         86.750        83.86
# 8       85.5         87.275        84.08
# 9       85.5         88.220        84.68
# 10      85.5         88.755        85.04
# 11      85.5         89.435        85.30
# 12      85.5         90.040        85.92
# 13      85.5         90.320        85.88
# 14      85.5         90.540        85.96
# 15      85.5         91.275        86.24
# 16      85.5         91.520        86.56
# 17      85.5         91.725        86.70
# 18      85.5         91.945        86.82
# 19      85.5         92.270        86.84
# 20      85.5         92.680        86.96
# 21      85.5         92.855        86.74
# 22      85.5         92.895        86.92
# 23      85.5         93.340        87.18
# 24      85.5         93.635        87.02
# 25      85.5         93.760        86.98
# 26      85.5         93.720        86.84
# 27      85.5         94.245        87.14
# 28      85.5         94.350        87.14
# 29      85.5         94.000        86.62

# %%
sns.set()
fig,ax=plt.subplots(figsize=(15,10))
l=locals()

x = np.arange(0 , 5, 1/6).reshape(-1,1)
for i in ['val_history','train_history']:
    l[i],=ax.plot(x, table[i], label=i)

ax.legend(loc = 'best')
plt.title('train acc and val acc')
plt.xlabel('epochs')
plt.ylabel('acc%')
plt.ylim(50,100)
plt.savefig('figure/acc_history.jpg')
plt.show()

# %%
print('test accuracy is: {}'.format(test_acc))
# Out:
# test accuracy is: 85.5

# %% [markdown]
# ### Print several predictions

# %%
model
# Out:
# BagOfWords(
#   (embed): Embedding(10002, 500, padding_idx=0)
#   (linear): Linear(in_features=500, out_features=20, bias=True)
# )

# %%
def prediction(loader, model):

    correct = 0
    total = 0
    model.eval()
    prediction = []
    label = []
    correct_pred = []
    incorrect_pred = []
    for data, lengths, labels in loader:
        data_batch, length_batch, label_batch = data, lengths, labels
        outputs = F.softmax(model(data_batch, length_batch), dim=1)
        predicted = outputs.max(1, keepdim=True)[1]

        equal = [x.item() for x in predicted.eq(labels.view_as(predicted))]
        for i in range(len(equal)):
            if equal[i] == 1:
                correct_pred.append([x.item() for x in data[i]])
            else:
                incorrect_pred.append([x.item() for x in data[i]])
                

    return correct_pred, incorrect_pred

# %%
correct_prediction, incorrect_prediction = prediction(val_loader, model)

# %%
len(correct_prediction), len(incorrect_prediction)
# Out:
# (4355, 645)

# %% [markdown]
# We randomly choose 5 correct predictions and 5 incorrect predictions

# %%
import random
correct_index = random.sample(range(len(correct_prediction)), 5)
incorrect_index = random.sample(range(len(incorrect_prediction)), 5)

# %%
for k, i in enumerate(correct_index):
    print('%s-th correct instance:'%str(k+1)+'\n'+' '.join([id2token[j] for j in correct_prediction[i] if id2token[j]!='<pad>']))
# Out:
# 1-th correct instance:
# i ended up watching this movie before even going through any of the reviews on the <unk> of a female just out of curiosity i thought let me find out if there are people who actually recommend others to watch this movie i am quite shocked to find such long and positive reviews on this website that makes me conclude that it 's a <unk> /><br />as far as my opinion goes i have to <unk> these filmmakers retarded or do they assume that the viewers are retarded the movie is atrocious on so many levels and i 'm not even talking about the story or <unk> /><br />so these bunch of guys plus one girl the lead actress form a music band guessing from the constant presence of <unk> it is supposed to be a rock band hell when did dancers started becoming the part of a rock band anyway let me accept it as the bollywood version of <unk> rock band but <unk> enough all the scores which actually had these two <unk> doing all kinds of cool rock gestures and i am assuming they were playing the <unk> the sound of the guitar was completely missing i
# 2-th correct instance:
# i had never seen such an incredible acting job in a motion picture as i did when i saw daniel day lewis play christy brown in my left foot in fact off the scene his role was n't even over he played the role of christy brown or at least disabled like him all through the filming of the movie and needed surgery because of the damage his superior acting had done to his back to me that is remarkable and through all the pain he put up with to act that role i believe it is quite true to say he put on the most oscar worthy performance in history he was so masterful in this tough a part that i believe no one could have done it better or with more of an impact than him although i can not say it is the greatest movie of all time i can say that how he played this impossible a role and then kept on acting it until it was n't even acting anymore is without a doubt the greatest feet i will ever seen an actor do probably a man too for that matter
# 3-th correct instance:
# bo derek will not go down in history as a great actress on the other hand starting in the 1980s actual acting talent seemed to be less and less of a required ability in hollywood so bo could very well have gone onto bigger and better things after the big box office take of blake <unk> 10 that is if she had n't allowed her husband john derek to take over her career numerous playboy <unk> and bad movies like this one this one in particular directed by john destroyed what momentum she had and made her the butt of many a joke in the 1980s it was assumed that you could put a certain personality in a certain movie and it would be box office gold john figured that putting bo in a movie <unk> she was nude for much of the running time would make people flock to the theaters after the 10 hype maybe if the movie had been any good perhaps this version of tarzan has got to be the all time worst of the many <unk> of <unk> 's lord of the jungle a slap in the face to character 's book and film legacy
# 4-th correct instance:
# i have rarely <unk> from viewing a film with such a warm happy feeling i felt as if i had been out with really good friends and had a wonderful time i thoroughly enjoyed this film the acting was superb although i would have to mention bill <unk> in particular as giving an absolutely <unk> performance bill is an excellent actor and would love to see him in more films timothy <unk> and jimmy nail are also favourites and always love to see them as they give such a solid performance and billy connolly as always totally gorgeous it was a wonderful ensemble performance from all concerned such a refreshing experience to see a well written superbly acted and good looking movie
# 5-th correct instance:
# as predictable as a hallmark card but not without merit the rookie makes for a solid outing dennis quaid the most reasonable jock actor working today is absolutely perfect as the science teacher turned baseball player jimmy morris the film is never <unk> down for the children as would be expected from a g rated film as a sports film the rookie is one of the best i have seen since any given sunday

# %%
for k, i in enumerate(incorrect_index):
    print('%s-th incorrect instance:'%str(k+1)+'\n'+' '.join([id2token[j] for j in incorrect_prediction[i] if id2token[j]!='<pad>']))
# Out:
# 1-th incorrect instance:
# mark <unk> 's <unk> <unk> of 1987 is a black comedy that is extremely cheesy in many parts but occasionally very funny nevertheless this movie could certainly have been a lot better the acting is terrible and some extremely cheesy scenes make it hard to watch at times but the concept is funny and it has some hilarious <unk> /><br />in the near future the year 1991 game shows have changed chuck <unk> john <unk> <unk> <unk> a game show called live or die in which convicted death row inmates have the chance to play for their lives and for money <unk> who fail get executed on the air using many different methods such as <unk> electric <unk> and other more bizarre devices of execution followed by applause from the cheering studio audience the show is of course more than controversial and chuck has made lots of enemies ... <br /><br <unk> <unk> is incredibly cheesy and crappy in many aspects and the acting is terrible but it is without doubt fun in many parts especially if you 're a fan of dark humor you have n't missed anything if you have n't seen it but it is definitely funny
# 2-th incorrect instance:
# a text prologue warns us that we should not allow evil to enter our house but i think the more apt word is <unk> good grief what <unk> these two babes <unk> /><br <unk> seymour <unk> is alone in his san francisco office and his <unk> expensive home in <unk> while his wife and child are away in san diego two girls sondra locke as jackson and <unk> camp as donna knock on his door asking directions well it 's <unk> and they 're <unk> like two <unk> pitiful <unk> and they 're not sure of the address they 're looking for and what with one thing and another george invites them to come in and <unk> of his pizza by the fire all three of them wind up in george 's bath <unk> and there follows about five minutes of mostly <unk> nudity in double exposure triple exposure <unk> exposure and <unk> exposure they spend the night in a <unk> and the next morning the girls fix him breakfast but something has gotten slightly <unk> because <unk> 's guests <unk> everything down with their fingers and pour <unk> and <unk> all over the <unk> and -- you eat like
# 3-th incorrect instance:
# i would love to have that two hours of my life back it seemed to be several clips from steve 's animal planet series that was <unk> into a loosely constructed script do n't go if you must see it wait for the video ...
# 4-th incorrect instance:
# <unk> really took the words right out of my mouth i loved segal 's early films and feel like the only one who is still faithful to him i just saw this movie ok fell asleep about 90 through so i did n't see the end when i woke up and saw i was at the dvd <unk> i was <unk> i did n't subject myself to any more of that movie and did n't dare find out what happened at the end there was something strange about the voice of segal and others kinda reminded me of the original mad max where the voice were dubbed but in the same language <unk> is english right :) anyway if i had 10 thumbs they 'd all point down right now for this segal injustice
# 5-th incorrect instance:
# when will the hurting stop i never want to see another version of a christmas carol again they keep on making movies with the same story falling over each other in trying to make the movie better then the rest but sadly fail to do so as this is not a good story <unk> old fashioned conservative happy thinking as if people learn the numerous different versions of this film prove that we <unk>

# %% [markdown]
# ### Global Search

# %%
table = {}
for i in n_gram:
    print('n_gram:',i)
    train_loader, val_loader, test_loader = data_loader(i)
    table[i] = []
    for opt in optimizers:
        train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, optimizer_name = opt,print_ = False )
        print('optimizers:%s, train accuracy:%.2f, test accuracy:%.2f, val accuracy:%.2f'%(opt, max(train_history), max(val_history),test_acc ))
        table[i].append({'n_gram': i, 'optimizers':opt,'val_history':val_history,'val_acc':max(val_history), 'train_history':train_history, 'train_acc':max(train_history), 'test_acc' :test_acc} )
    for vs in vocab_sizes:
        train_history, val_history, test_acc = compare_model(train_loader, val_loader, test_loader, vocab_size = vs,print_ = False )
        print('vocab_sizes:%s, train accuracy:%.2f, test accuracy:%.2f, val accuracy:%.2f'%(vs, max(train_history), max(val_history),test_acc ))
        table[i].append({'n_gram': i, 'vocab_size':vs,'val_history':val_history,'val_acc':max(val_history), 'train_history':train_history, 'train_acc':max(train_history),'test_acc' :test_acc} )
    for lr in learning_rates:
        val_history, test_acc = compare_model(train_loader, val_loader, test_loader, learning_rate = lr,print_ = False )
        print('learning rate:%s, train accuracy:%.2f, test accuracy:%.2f, val accuracy:%.2f'%(lr, max(train_history), max(val_history),test_acc ))
        table[i].append({'n_gram': i, 'learning_rate':lr,'val_history':val_history,'val_acc':max(val_history), 'test_acc' :test_acc} )
    for ed in embed_dims:
        val_history, test_acc = compare_model(train_loader, val_loader, test_loader, emb_dim = ed,print_ = False )
        print('learning rate:%s, train accuracy:%.2f, test accuracy:%.2f, val accuracy:%.2f'%(lr, max(train_history), max(val_history),test_acc ))
        table[i].append({'n_gram': i, 'emb_dim':ed,'val_history':val_history,'val_acc':max(val_history), 'test_acc' :test_acc} )
    val_history, test_acc = compare_model(train_loader, val_loader, test_loader, annealing_learing = True,print_ = False )
    table[i].append({'n_gram': i, 'annealing_learing':True,'val_history':val_history,'val_acc':max(val_history), 'test_acc' :test_acc})
    df = pd.DataFrame(table[i])
    df.emb_dim = df.emb_dim.fillna(500)
    df.learning_rate = df.learning_rate.fillna(0.001)
    df.vocab_size = df.vocab_size.fillna(10002)
    df.optimizers = df.optimizers.fillna('Adam')
    df.annealing_learing = df.annealing_learing.fillna(True)
    df.to_csv('table_%s_gram.csv'%i)
